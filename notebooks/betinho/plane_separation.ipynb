# %% [markdown]
# # Separamos os dados de cada avião e botamos em plane_data

# %%
import pandas as pd
import numpy as np
df = pd.read_parquet('./agregated_data/min.parquet')

# %%
for value in df["aircraftSerNum-1"].unique():
    df[df["aircraftSerNum-1"] == value].to_parquet(f'./plane_data//{value}.parquet')

# %%
df2 = pd.read_parquet('./plane_data/20018.0.parquet')
df2
# Out:
#        recording_time  aircraftSerNum-1  amscChBasHealthStatus-1b  \
# 28546               0           20018.0                       0.0
# 28547               0           20018.0                       0.0
# 28548               0           20018.0                       0.0
# 28549               0           20018.0                       0.0
# 28550               0           20018.0                       0.0
# ...               ...               ...                       ...
# 31075               0           20018.0                       0.0
# 31076               0           20018.0                       0.0
# 31077               0           20018.0                       0.0
# 31078               0           20018.0                       0.0
# 31079               0           20018.0                       0.0
#
#        amscChBasHealthStatus-1a  amscChBasHealthStatus-2b  amscHprsovDrivF-1a  \
# 28546                       0.0                       0.0                 0.0
# ...
